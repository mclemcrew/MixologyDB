# %%
# !pip install pandas
# !pip install numpy
# !pip install pyloudnorm
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: pyloudnorm in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (0.1.1)
# Requirement already satisfied: scipy>=1.0.1 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from pyloudnorm) (1.13.1)
# Requirement already satisfied: numpy>=1.14.2 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from pyloudnorm) (1.26.4)
# Requirement already satisfied: future>=0.16.0 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from pyloudnorm) (1.0.0)
# Collecting matplotlib
#   Downloading matplotlib-3.9.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.2/162.2 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from matplotlib) (24.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.0-cp311-cp311-macosx_11_0_arm64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 27.9 MB/s eta 0:00:00a 0:00:01
# Downloading contourpy-1.2.1-cp311-cp311-macosx_11_0_arm64.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.9/245.9 kB 21.8 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.0-cp311-cp311-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 37.5 MB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 9.7 MB/s eta 0:00:00
# Downloading pillow-10.3.0-cp311-cp311-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 44.5 MB/s eta 0:00:00a 0:00:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 15.6 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.0 kiwisolver-1.4.5 matplotlib-3.9.0 pillow-10.3.0 pyparsing-3.1.2

# %% [markdown]
# ## Data Wrangling for Mixes

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

df = pd.read_json("../final-track-data.json")
mixes_df = pd.json_normalize(df["mixes"])
mixes_df.head(5)
# Out:
#   mix-name song-name    artist-name     genre  \
# 0   PXL-L1   Vermont  The Districts  POP ROCK
# 1   PXL-L2   Vermont  The Districts  POP ROCK
# 2   PXL-L3   Vermont  The Districts  POP ROCK
# 3   PXL-L4   Vermont  The Districts  POP ROCK
# 4   PXL-L5   Vermont  The Districts  POP ROCK
#
#                                       mix-evaluation  \
# 0  [{'track-num-eval': 0.76, 'track-semantic-eval...
# 1  [{'track-num-eval': 0.79, 'track-semantic-eval...
# 2  [{'track-num-eval': 0.51, 'track-semantic-eval...
# 3  [{'track-num-eval': 0.77, 'track-semantic-eval...
# 4  [{'track-num-eval': 0.66, 'track-semantic-eval...
#
#                                               tracks
# 0  [{'track-name': 'Kick In', 'track-type': 'AUDI...
# 1  [{'track-name': 'Kick IN', 'track-type': 'AUDI...
# 2  [{'track-name': 'K in', 'track-type': 'AUDIO',...
# 3  [{'track-name': 'KickIn_15', 'track-type': 'AU...
# 4  [{'track-name': 'KickIn_15', 'track-type': 'AU...

# %% [markdown]
# ### Looping through the tracks for each mix

# %%
# Create a multiple dimensional array for the tracks in each mix
mixes = []
for i, row in mixes_df.iterrows():
    print(row)
    mixes.append(row["tracks"])
    
# print(mixes)

track_count = 0

for mix in mixes:
    for track in mix:
        track_count += 1
        
print(track_count)
# Out:
# mix-name                                                     PXL-L1
# song-name                                                   Vermont
# artist-name                                           The Districts
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.76, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick In', 'track-type': 'AUDI...
# Name: 0, dtype: object
# mix-name                                                     PXL-L2
# song-name                                                   Vermont
# artist-name                                           The Districts
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.79, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick IN', 'track-type': 'AUDI...
# Name: 1, dtype: object
# mix-name                                                     PXL-L3
# song-name                                                   Vermont
# artist-name                                           The Districts
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.51, 'track-semantic-eval...
# tracks            [{'track-name': 'K in', 'track-type': 'AUDIO',...
# Name: 2, dtype: object
# mix-name                                                     PXL-L4
# song-name                                                   Vermont
# artist-name                                           The Districts
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.77, 'track-semantic-eval...
# tracks            [{'track-name': 'KickIn_15', 'track-type': 'AU...
# Name: 3, dtype: object
# mix-name                                                     PXL-L5
# song-name                                                   Vermont
# artist-name                                           The Districts
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.66, 'track-semantic-eval...
# tracks            [{'track-name': 'KickIn_15', 'track-type': 'AU...
# Name: 4, dtype: object
# mix-name                                                      DU-P2
# song-name                                                   Vermont
# artist-name                                           The Districts
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.6900000000000001, 'track...
# tracks            [{'track-name': 'KickIn', 'track-type': 'AUDIO...
# Name: 5, dtype: object
# mix-name                                                      DU-O2
# song-name                                                   Vermont
# artist-name                                           The Districts
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.27, 'track-semantic-eval...
# tracks            [{'track-name': 'KickIn_15', 'track-type': 'AU...
# Name: 6, dtype: object
# mix-name                                                     UCP-B1
# song-name                                                 Good Time
# artist-name                                       Louis Cressy Band
# genre                                                          ROCK
# mix-evaluation    [{'track-num-eval': 0.6900000000000001, 'track...
# tracks            [{'track-name': 'KickIn', 'track-type': 'AUDIO...
# Name: 7, dtype: object
# mix-name                                                     UCP-B3
# song-name                                                 Good Time
# artist-name                                       Louis Cressy Band
# genre                                                          ROCK
# mix-evaluation    [{'track-num-eval': 0.39, 'track-semantic-eval...
# tracks            [{'track-name': '01_KickIn', 'track-type': 'AU...
# Name: 8, dtype: object
# mix-name                                                     UCP-B4
# song-name                                                 Good Time
# artist-name                                       Louis Cressy Band
# genre                                                          ROCK
# mix-evaluation    [{'track-num-eval': 0.09, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick In', 'track-type': 'AUDI...
# Name: 9, dtype: object
# mix-name                                                     UCP-B1
# song-name                                             Sea Of Leaves
# artist-name                                   Jokers, Jacks & Kings
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.34, 'track-semantic-eval...
# tracks            [{'track-name': 'KickIn', 'track-type': 'AUDIO...
# Name: 10, dtype: object
# mix-name                                                     UCP-B3
# song-name                                             Sea Of Leaves
# artist-name                                   Jokers, Jacks & Kings
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.1, 'track-semantic-eval'...
# tracks            [{'track-name': '01_KickIn', 'track-type': 'AU...
# Name: 11, dtype: object
# mix-name                                                     UCP-B4
# song-name                                             Sea Of Leaves
# artist-name                                   Jokers, Jacks & Kings
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.12, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick In', 'track-type': 'AUDI...
# Name: 12, dtype: object
# mix-name                                                     UCP-B2
# song-name                                             Sea Of Leaves
# artist-name                                   Jokers, Jacks & Kings
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.14, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick', 'track-type': 'AUDIO',...
# Name: 13, dtype: object
# mix-name                                                     UCP-A1
# song-name                                                    Lolita
# artist-name                                            Purling Hiss
# genre                                                     Hard Rock
# mix-evaluation    [{'track-num-eval': 0.1, 'track-semantic-eval'...
# tracks            [{'track-name': 'Kick_07', 'track-type': 'AUDI...
# Name: 14, dtype: object
# mix-name                                                     UCP-A2
# song-name                                                    Lolita
# artist-name                                            Purling Hiss
# genre                                                     Hard Rock
# mix-evaluation    [{'track-num-eval': 0.06, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick_07', 'track-type': 'AUDI...
# Name: 15, dtype: object
# mix-name                                                     UCP-A3
# song-name                                                    Lolita
# artist-name                                            Purling Hiss
# genre                                                     Hard Rock
# mix-evaluation    [{'track-num-eval': 0.16, 'track-semantic-eval...
# tracks            [{'track-name': 'BassAmp.01_01', 'track-type':...
# Name: 16, dtype: object
# mix-name                                                     UCP-A4
# song-name                                                    Lolita
# artist-name                                            Purling Hiss
# genre                                                     Hard Rock
# mix-evaluation    [{'track-num-eval': 0.2, 'track-semantic-eval'...
# tracks            [{'track-name': 'Kick_07', 'track-type': 'AUDI...
# Name: 17, dtype: object
# mix-name                                                     UCP-A5
# song-name                                                    Lolita
# artist-name                                            Purling Hiss
# genre                                                     Hard Rock
# mix-evaluation    [{'track-num-eval': 0.32, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick_07', 'track-type': 'AUDI...
# Name: 18, dtype: object
# mix-name                                                     UCP-A1
# song-name                                                  Old Tree
# artist-name                                                Creepoid
# genre                                                    Indie Rock
# mix-evaluation    [{'track-num-eval': 0.14, 'track-semantic-eval...
# tracks            [{'track-name': 'VOX SM7 COMP_01.1', 'track-ty...
# Name: 19, dtype: object
# mix-name                                                     UCP-A2
# song-name                                                  Old Tree
# artist-name                                                Creepoid
# genre                                                    Indie Rock
# mix-evaluation    [{'track-num-eval': 0.66, 'track-semantic-eval...
# tracks            [{'track-name': 'VOX SM7 COMP_01', 'track-type...
# Name: 20, dtype: object
# mix-name                                                     UCP-A3
# song-name                                                  Old Tree
# artist-name                                                Creepoid
# genre                                                    Indie Rock
# mix-evaluation    [{'track-num-eval': 0.31, 'track-semantic-eval...
# tracks            [{'track-name': 'VOX 260 COMP_01', 'track-type...
# Name: 21, dtype: object
# mix-name                                                     UCP-A4
# song-name                                                  Old Tree
# artist-name                                                Creepoid
# genre                                                    Indie Rock
# mix-evaluation    [{'track-num-eval': 0.47000000000000003, 'trac...
# tracks            [{'track-name': 'KickIn COMP_01', 'track-type'...
# Name: 22, dtype: object
# mix-name                                                     UCP-A5
# song-name                                                  Old Tree
# artist-name                                                Creepoid
# genre                                                    Indie Rock
# mix-evaluation    [{'track-num-eval': 0.2, 'track-semantic-eval'...
# tracks            [{'track-name': 'KickIn COMP_01', 'track-type'...
# Name: 23, dtype: object
# mix-name                                                     UCP-B1
# song-name                                      You & Me & the Radio
# artist-name                                             Human Radio
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.19, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick', 'track-type': 'AUDIO',...
# Name: 24, dtype: object
# mix-name                                                     UCP-B2
# song-name                                      You & Me & the Radio
# artist-name                                             Human Radio
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.29, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick', 'track-type': 'AUDIO',...
# Name: 25, dtype: object
# mix-name                                                     UCP-B3
# song-name                                      You & Me & the Radio
# artist-name                                             Human Radio
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.68, 'track-semantic-eval...
# tracks            [{'track-name': '01_Kick_TelefunkenM82', 'trac...
# Name: 26, dtype: object
# mix-name                                                     UCP-B4
# song-name                                      You & Me & the Radio
# artist-name                                             Human Radio
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.09, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick', 'track-type': 'AUDIO',...
# Name: 27, dtype: object
# mix-name                                                      MgC-Q
# song-name                                              Pouring Room
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.8200000000000001, 'track...
# tracks            [{'track-name': 'Kin.09', 'track-type': 'AUDIO...
# Name: 28, dtype: object
# mix-name                                                      MgC-R
# song-name                                              Pouring Room
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.02, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin.09', 'track-type': 'AUDIO...
# Name: 29, dtype: object
# mix-name                                                      MgC-S
# song-name                                              Pouring Room
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.18, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin.09', 'track-type': 'AUDIO...
# Name: 30, dtype: object
# mix-name                                                      MgC-T
# song-name                                              Pouring Room
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.73, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin.09', 'track-type': 'AUDIO...
# Name: 31, dtype: object
# mix-name                                                      MgC-U
# song-name                                              Pouring Room
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.76, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin.09', 'track-type': 'AUDIO...
# Name: 32, dtype: object
# mix-name                                                      MgC-V
# song-name                                              Pouring Room
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.24, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin.09', 'track-type': 'AUDIO...
# Name: 33, dtype: object
# mix-name                                                      MgC-W
# song-name                                              Pouring Room
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.13, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin.09', 'track-type': 'AUDIO...
# Name: 34, dtype: object
# mix-name                                                      MgC-X
# song-name                                              Pouring Room
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.15, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin.09', 'track-type': 'AUDIO...
# Name: 35, dtype: object
# mix-name                                                      MgC-I
# song-name                                       Under A Covered Sky
# artist-name                                            The DoneFors
# genre                                                           POP
# mix-evaluation    [{'track-num-eval': 0.08, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin', 'track-type': 'AUDIO', ...
# Name: 36, dtype: object
# mix-name                                                      MgC-J
# song-name                                       Under A Covered Sky
# artist-name                                            The DoneFors
# genre                                                           POP
# mix-evaluation    [{'track-num-eval': 0.4, 'track-semantic-eval'...
# tracks            [{'track-name': 'Kin CONS', 'track-type': 'AUD...
# Name: 37, dtype: object
# mix-name                                                      MgC-K
# song-name                                       Under A Covered Sky
# artist-name                                            The DoneFors
# genre                                                           POP
# mix-evaluation    [{'track-num-eval': 0.86, 'track-semantic-eval...
# tracks            [{'track-name': 'LDVoc147C1 CONS', 'track-type...
# Name: 38, dtype: object
# mix-name                                                      MgC-L
# song-name                                       Under A Covered Sky
# artist-name                                            The DoneFors
# genre                                                           POP
# mix-evaluation    [{'track-num-eval': 0.51, 'track-semantic-eval...
# tracks            [{'track-name': 'LDVoc147C1 CONS', 'track-type...
# Name: 39, dtype: object
# mix-name                                                      MgC-M
# song-name                                       Under A Covered Sky
# artist-name                                            The DoneFors
# genre                                                           POP
# mix-evaluation    [{'track-num-eval': 0.78, 'track-semantic-eval...
# tracks            [{'track-name': 'Kik', 'track-type': 'AUDIO', ...
# Name: 40, dtype: object
# mix-name                                                      MgC-N
# song-name                                       Under A Covered Sky
# artist-name                                            The DoneFors
# genre                                                           POP
# mix-evaluation    [{'track-num-eval': 0.74, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin CONS', 'track-type': 'AUD...
# Name: 41, dtype: object
# mix-name                                                      MgC-O
# song-name                                       Under A Covered Sky
# artist-name                                            The DoneFors
# genre                                                           POP
# mix-evaluation    [{'track-num-eval': 0.29, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin CONS', 'track-type': 'AUD...
# Name: 42, dtype: object
# mix-name                                                      MgC-P
# song-name                                       Under A Covered Sky
# artist-name                                            The DoneFors
# genre                                                           POP
# mix-evaluation    [{'track-num-eval': 1, 'track-semantic-eval': ...
# tracks            [{'track-name': 'K in', 'track-type': 'AUDIO',...
# Name: 43, dtype: object
# mix-name                                                      McG-A
# song-name                                                   Lead Me
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.35000000000000003, 'trac...
# tracks            [{'track-name': 'KOut', 'track-type': 'AUDIO',...
# Name: 44, dtype: object
# mix-name                                                      McG-B
# song-name                                                   Lead Me
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.51, 'track-semantic-eval...
# tracks            [{'track-name': 'Act Guit (Stereo)', 'track-ty...
# Name: 45, dtype: object
# mix-name                                                      McG-C
# song-name                                                   Lead Me
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.4, 'track-semantic-eval'...
# tracks            [{'track-name': 'Kin', 'track-type': 'AUDIO', ...
# Name: 46, dtype: object
# mix-name                                                      McG-D
# song-name                                                   Lead Me
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.48, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin', 'track-type': 'AUDIO', ...
# Name: 47, dtype: object
# mix-name                                                      McG-E
# song-name                                                   Lead Me
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.54, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin', 'track-type': 'AUDIO', ...
# Name: 48, dtype: object
# mix-name                                                      McG-F
# song-name                                                   Lead Me
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.84, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin', 'track-type': 'AUDIO', ...
# Name: 49, dtype: object
# mix-name                                                      McG-G
# song-name                                                   Lead Me
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.44, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin', 'track-type': 'AUDIO', ...
# Name: 50, dtype: object
# mix-name                                                      McG-H
# song-name                                                   Lead Me
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.56, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin', 'track-type': 'AUDIO', ...
# Name: 51, dtype: object
# mix-name                                                     UCP-A1
# song-name                                                   Lead Me
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.5, 'track-semantic-eval'...
# tracks            [{'track-name': 'JanineVoc', 'track-type': 'AU...
# Name: 52, dtype: object
# mix-name                                                     UCP-A2
# song-name                                                   Lead Me
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.42, 'track-semantic-eval...
# tracks            [{'track-name': 'LeadVoc', 'track-type': 'AUDI...
# Name: 53, dtype: object
# mix-name                                                     UCP-A3
# song-name                                                   Lead Me
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.30000000000000004, 'trac...
# tracks            [{'track-name': 'LeadVoc', 'track-type': 'AUDI...
# Name: 54, dtype: object
# mix-name                                                     UCP-A4
# song-name                                                   Lead Me
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.1, 'track-semantic-eval'...
# tracks            [{'track-name': 'KOut', 'track-type': 'AUDIO',...
# Name: 55, dtype: object
# mix-name                                                     UCP-A5
# song-name                                                   Lead Me
# artist-name                                            The DoneFors
# genre                                                       COUNTRY
# mix-evaluation    [{'track-num-eval': 0.65, 'track-semantic-eval...
# tracks            [{'track-name': 'Kin', 'track-type': 'AUDIO', ...
# Name: 56, dtype: object
# mix-name                                                      McG-A
# song-name                                           In The Meantime
# artist-name                                                 Fredy V
# genre                                                          FUNK
# mix-evaluation    [{'track-num-eval': 0.74, 'track-semantic-eval...
# tracks            [{'track-name': 'KIn CONS', 'track-type': 'AUD...
# Name: 57, dtype: object
# mix-name                                                      McG-B
# song-name                                           In The Meantime
# artist-name                                                 Fredy V
# genre                                                          FUNK
# mix-evaluation    [{'track-num-eval': 0.36, 'track-semantic-eval...
# tracks            [{'track-name': 'KIn CONS', 'track-type': 'AUD...
# Name: 58, dtype: object
# mix-name                                                      McG-C
# song-name                                           In The Meantime
# artist-name                                                 Fredy V
# genre                                                          FUNK
# mix-evaluation    [{'track-num-eval': 0.45, 'track-semantic-eval...
# tracks            [{'track-name': 'KIn', 'track-type': 'AUDIO', ...
# Name: 59, dtype: object
# mix-name                                                      McG-D
# song-name                                           In The Meantime
# artist-name                                                 Fredy V
# genre                                                          FUNK
# mix-evaluation    [{'track-num-eval': 0.78, 'track-semantic-eval...
# tracks            [{'track-name': 'KIn CONS', 'track-type': 'AUD...
# Name: 60, dtype: object
# mix-name                                                      McG-E
# song-name                                           In The Meantime
# artist-name                                                 Fredy V
# genre                                                          FUNK
# mix-evaluation    [{'track-num-eval': 0.5, 'track-semantic-eval'...
# tracks            [{'track-name': 'KOut CONS', 'track-type': 'AU...
# Name: 61, dtype: object
# mix-name                                                      McG-F
# song-name                                           In The Meantime
# artist-name                                                 Fredy V
# genre                                                          FUNK
# mix-evaluation    [{'track-num-eval': 0.12, 'track-semantic-eval...
# tracks            [{'track-name': 'KIn CONS', 'track-type': 'AUD...
# Name: 62, dtype: object
# mix-name                                                      McG-G
# song-name                                           In The Meantime
# artist-name                                                 Fredy V
# genre                                                          FUNK
# mix-evaluation    [{'track-num-eval': 0.18, 'track-semantic-eval...
# tracks            [{'track-name': 'KIn CONS', 'track-type': 'AUD...
# Name: 63, dtype: object
# mix-name                                                      McG-H
# song-name                                           In The Meantime
# artist-name                                                 Fredy V
# genre                                                          FUNK
# mix-evaluation    [{'track-num-eval': 0.75, 'track-semantic-eval...
# tracks            [{'track-name': 'KIn CONS', 'track-type': 'AUD...
# Name: 64, dtype: object
# mix-name                                                     UCP-A1
# song-name                                           In The Meantime
# artist-name                                                 Fredy V
# genre                                                          FUNK
# mix-evaluation    [{'track-num-eval': 0.28, 'track-semantic-eval...
# tracks            [{'track-name': 'LDC2', 'track-type': 'AUDIO',...
# Name: 65, dtype: object
# mix-name                                                     UCP-A2
# song-name                                           In The Meantime
# artist-name                                                 Fredy V
# genre                                                          FUNK
# mix-evaluation    [{'track-num-eval': 0.79, 'track-semantic-eval...
# tracks            [{'track-name': 'LDC2', 'track-type': 'AUDIO',...
# Name: 66, dtype: object
# mix-name                                                     UCP-A3
# song-name                                           In The Meantime
# artist-name                                                 Fredy V
# genre                                                          FUNK
# mix-evaluation    [{'track-num-eval': 0.31, 'track-semantic-eval...
# tracks            [{'track-name': 'LDC2', 'track-type': 'AUDIO',...
# Name: 67, dtype: object
# mix-name                                                      McG-A
# song-name                                                 Not Alone
# artist-name                                                 Fredy V
# genre                                                          SOUL
# mix-evaluation    [{'track-num-eval': 0.5700000000000001, 'track...
# tracks            [{'track-name': 'KIn', 'track-type': 'AUDIO', ...
# Name: 68, dtype: object
# mix-name                                                      McG-B
# song-name                                                 Not Alone
# artist-name                                                 Fredy V
# genre                                                          SOUL
# mix-evaluation    [{'track-num-eval': 0, 'track-semantic-eval': ...
# tracks            [{'track-name': 'KIn', 'track-type': 'AUDIO', ...
# Name: 69, dtype: object
# mix-name                                                      McG-C
# song-name                                                 Not Alone
# artist-name                                                 Fredy V
# genre                                                          SOUL
# mix-evaluation    [{'track-num-eval': 0.62, 'track-semantic-eval...
# tracks            [{'track-name': 'KIn', 'track-type': 'AUDIO', ...
# Name: 70, dtype: object
# mix-name                                                      McG-D
# song-name                                                 Not Alone
# artist-name                                                 Fredy V
# genre                                                          SOUL
# mix-evaluation    [{'track-num-eval': 0.51, 'track-semantic-eval...
# tracks            [{'track-name': 'KIn', 'track-type': 'AUDIO', ...
# Name: 71, dtype: object
# mix-name                                                      McG-E
# song-name                                                 Not Alone
# artist-name                                                 Fredy V
# genre                                                          SOUL
# mix-evaluation    [{'track-num-eval': 0.88, 'track-semantic-eval...
# tracks            [{'track-name': 'KIn', 'track-type': 'AUDIO', ...
# Name: 72, dtype: object
# mix-name                                                      McG-F
# song-name                                                 Not Alone
# artist-name                                                 Fredy V
# genre                                                          SOUL
# mix-evaluation    [{'track-num-eval': 0.30000000000000004, 'trac...
# tracks            [{'track-name': 'KIn', 'track-type': 'AUDIO', ...
# Name: 73, dtype: object
# mix-name                                                      McG-G
# song-name                                                 Not Alone
# artist-name                                                 Fredy V
# genre                                                          SOUL
# mix-evaluation    [{'track-num-eval': 0.6000000000000001, 'track...
# tracks            [{'track-name': 'KIn', 'track-type': 'AUDIO', ...
# Name: 74, dtype: object
# mix-name                                                      McG-H
# song-name                                                 Not Alone
# artist-name                                                 Fredy V
# genre                                                          SOUL
# mix-evaluation    [{'track-num-eval': 0.67, 'track-semantic-eval...
# tracks            [{'track-name': 'KIn', 'track-type': 'AUDIO', ...
# Name: 75, dtype: object
# mix-name                                                      McG-A
# song-name                                               Red To Blue
# artist-name                                            Broken Crank
# genre                                                          ROCK
# mix-evaluation    [{'track-num-eval': 0.67, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick', 'track-type': 'AUDIO',...
# Name: 76, dtype: object
# mix-name                                                      McG-B
# song-name                                               Red To Blue
# artist-name                                            Broken Crank
# genre                                                          ROCK
# mix-evaluation    [{'track-num-eval': 0.6000000000000001, 'track...
# tracks            [{'track-name': 'Kick', 'track-type': 'AUDIO',...
# Name: 77, dtype: object
# mix-name                                                      McG-C
# song-name                                               Red To Blue
# artist-name                                            Broken Crank
# genre                                                          ROCK
# mix-evaluation    [{'track-num-eval': 0.99, 'track-semantic-eval...
# tracks            [{'track-name': 'OH L', 'track-type': 'AUDIO',...
# Name: 78, dtype: object
# mix-name                                                      McG-D
# song-name                                               Red To Blue
# artist-name                                            Broken Crank
# genre                                                          ROCK
# mix-evaluation    [{'track-num-eval': 0.58, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick', 'track-type': 'AUDIO',...
# Name: 79, dtype: object
# mix-name                                                      McG-E
# song-name                                               Red To Blue
# artist-name                                            Broken Crank
# genre                                                          ROCK
# mix-evaluation    [{'track-num-eval': 0.96, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick', 'track-type': 'AUDIO',...
# Name: 80, dtype: object
# mix-name                                                      McG-F
# song-name                                               Red To Blue
# artist-name                                            Broken Crank
# genre                                                          ROCK
# mix-evaluation    [{'track-num-eval': 0.31, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick', 'track-type': 'AUDIO',...
# Name: 81, dtype: object
# mix-name                                                      McG-G
# song-name                                               Red To Blue
# artist-name                                            Broken Crank
# genre                                                          ROCK
# mix-evaluation    [{'track-num-eval': 0.5, 'track-semantic-eval'...
# tracks            [{'track-name': 'Kick', 'track-type': 'AUDIO',...
# Name: 82, dtype: object
# mix-name                                                      McG-H
# song-name                                               Red To Blue
# artist-name                                            Broken Crank
# genre                                                          ROCK
# mix-evaluation    [{'track-num-eval': 0.93, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick', 'track-type': 'AUDIO',...
# Name: 83, dtype: object
# mix-name                                                     PXL-S1
# song-name                                          I'd Like To Know
# artist-name                                              Flithybird
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.61, 'track-semantic-eval...
# tracks            [{'track-name': 'KickBatter_16', 'track-type':...
# Name: 84, dtype: object
# mix-name                                                     PXL-S2
# song-name                                          I'd Like To Know
# artist-name                                              Flithybird
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.58, 'track-semantic-eval...
# tracks            [{'track-name': 'KickBatter_16', 'track-type':...
# Name: 85, dtype: object
# mix-name                                 Productieanalyse LOGIC MIX
# song-name                                          I'd Like To Know
# artist-name                                              Flithybird
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.64, 'track-semantic-eval...
# tracks            [{'track-name': 'Tmb.01_03', 'track-type': 'AU...
# Name: 86, dtype: object
# mix-name                                                     PXL-S5
# song-name                                          I'd Like To Know
# artist-name                                              Flithybird
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.62, 'track-semantic-eval...
# tracks            [{'track-name': 'KickBatter_16', 'track-type':...
# Name: 87, dtype: object
# mix-name                                                     PXL-S6
# song-name                                          I'd Like To Know
# artist-name                                              Flithybird
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.6000000000000001, 'track...
# tracks            [{'track-name': 'Kick_02', 'track-type': 'AUDI...
# Name: 88, dtype: object
# mix-name                                                     PXL-S7
# song-name                                          I'd Like To Know
# artist-name                                              Flithybird
# genre                                                      POP ROCK
# mix-evaluation    [{'track-num-eval': 0.65, 'track-semantic-eval...
# tracks            [{'track-name': 'Kick_02', 'track-type': 'AUDI...
# Name: 89, dtype: object
# 2411

# %%
# !pip install datasets
# !pip install HfApi
# Out:
# Requirement already satisfied: datasets in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (2.19.1)
# Requirement already satisfied: filelock in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from datasets) (0.23.2)
# Requirement already satisfied: packaging in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from huggingface-hub>=0.21.2->datasets) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from pandas->datasets) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Collecting HfApi
#   Downloading hfapi-0.1b0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: requests in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from HfApi) (2.32.3)
# Requirement already satisfied: aiohttp in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from HfApi) (3.9.5)
# Requirement already satisfied: pydantic in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from HfApi) (2.7.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from aiohttp->HfApi) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from aiohttp->HfApi) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from aiohttp->HfApi) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from aiohttp->HfApi) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from aiohttp->HfApi) (1.9.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from pydantic->HfApi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from pydantic->HfApi) (2.18.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from pydantic->HfApi) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from requests->HfApi) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from requests->HfApi) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from requests->HfApi) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mclem/Development/MixologyDB/.conda/lib/python3.11/site-packages (from requests->HfApi) (2024.6.2)
# Downloading hfapi-0.1b0-py3-none-any.whl (14 kB)
# Installing collected packages: HfApi
# Successfully installed HfApi-0.1b0

# %%
import json
from datasets import Dataset, DatasetDict

# Load the JSON data
with open("../final-track-data.json", "r") as file:
    data = json.load(file)

# Extract the relevant information from the JSON
track_data = []
for mix in data["mixes"]:
    mix_name = mix["mix-name"]
    song_name = mix["song-name"]
    artist_name = mix["artist-name"]
    genre = mix["genre"]
    
    for track in mix["tracks"]:
        if track["track-type"] == "AUDIO":
            track_name = track["track-name"]
            track_type = track["track-type"]
            track_instrument_subtype = track["track-instrument-subtype"]
            track_instrument_type = track["track-instrument-type"]
            channel_mode = track["channel-mode"]
            track_audio_features = track["track-audio-features"]
            parameters = json.dumps(track["parameters"])
                
            track_data.append({
                "mix_name": mix_name,
                "song_name": song_name,
                "artist_name": artist_name,
                "genre": genre,
                "track_name": track_name,
                "track_type": track_type,
                "track_instrument_subtype": track_instrument_subtype,
                "track_instrument_type": track_instrument_type,
                "channel_mode": channel_mode,
                "track_audio_path": track_audio_features['track-audio-path'],
                "track_audio_sample_rate": track_audio_features['track-audio-sample-rate'],
                "track_audio_lufs": track_audio_features['track-audio-lufs'],
                "parameters": parameters
            })

# %%
# Create a Dataset from the extracted track data
dataset = Dataset.from_list(track_data)

shuffled_dataset = dataset.shuffle(seed=42)
shuffled_dataset["genre"][:10]

# Split the dataset into train, dev, and test sets
train_dataset = shuffled_dataset.select(range(1545))
dev_dataset = shuffled_dataset.select(range(1545, 1845))
test_dataset = shuffled_dataset.select(range(1845, 2345))

# Create a DatasetDict with the splits
dataset_dict = DatasetDict({
    "train": train_dataset,
    "dev": dev_dataset,
    "test": test_dataset
})

# %%
from huggingface_hub import HfApi

# Push the dataset to your Hugging Face account
api = HfApi()
username = "mclemcrew"  # Replace with your Hugging Face username
dataset_name = "mix-evaluation-dataset"  # Choose a name for your dataset

# %%
dataset_dict.push_to_hub(
    repo_id=f"{username}/{dataset_name}",
    private=False,  # Set to False if you want the dataset to be public
    token=""  # Replace with your Hugging Face token
)
# Out:
# Creating parquet from Arrow format: 100%|██████████| 2/2 [00:00<00:00, 22.57ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:00<00:00,  1.45it/s]
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 35.80ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 30.54ba/s]
# Uploading the dataset shards: 100%|██████████| 1/1 [00:00<00:00,  2.46it/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/mclemcrew/mix-evaluation-dataset/commit/df15a107cf86ed46793df859daf43d5f24b142fd', commit_message='Upload dataset', commit_description='', oid='df15a107cf86ed46793df859daf43d5f24b142fd', pr_url=None, pr_revision=None, pr_num=None)

# %%
# Number of each audio effect for each track
eq_count = 0
gate_count = 0
compression_count = 0
reverb_count = 0
delay_count = 0
flanger_count = 0
phaser_count = 0
chorus_count = 0
track_count = 0

for mix in mixes:
    for track in mix:
        track_count += 1
        for key, value in track.items():     
            if(key == "parameters"):
                if("eq" in value):
                    eq_count += 1
                if("gate" in value):
                    gate_count += len(value['gate'])
                if("compression" in value):
                    compression_count += len(value['compression'])
                if("reverb" in value):
                    reverb_count += len(value['reverb'])
                if("delay" in value):
                    delay_count += len(value['delay'])
                if("flanger" in value):
                    flanger_count += len(value['flanger'])
                if("phaser" in value):
                    phaser_count += len(value['phaser'])
                if("chorus" in value):
                    chorus_count += len(value['chorus'])

print(f"Number of EQs used: {eq_count}")
print(f"Number of gates used: {gate_count}")
print(f"Number of compressions used: {compression_count}")
print(f"Number of reverbs used: {reverb_count}")
print(f"Number of delays used: {delay_count}")
print(f"Number of flangers used: {flanger_count}")
print(f"Number of phasers used: {phaser_count}")
print(f"Number of choruses used: {chorus_count}")
print(f"Number of total tracks: {track_count}")
# Out:
# Number of EQs used: 1628
# Number of gates used: 249
# Number of compressions used: 1444
# Number of reverbs used: 1465
# Number of delays used: 124
# Number of flangers used: 4
# Number of phasers used: 6
# Number of choruses used: 10
# Number of total tracks: 2411

# %% [markdown]
# ## Getting data in a dataframe for easy reading and analysis
#
# #### Could one hot encode the vector
# | EQ | Gate | Compression | Reverb | Delay | Flanger | Phaser | Chorus |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# |   1 |   1 |    0 |    0 |    0 |    1 |    1 |    1 |
#
#
# #### Or for training with a neural network arch, could do something like this for the data:
# | Track | Effects |
# | --- | --- |
# |   OVERHEADS |   [COMPRESSION, REVERB, DELAY] |

# %%
# tracks_information = []

# for mix in mixes: 
#     for track in mix:
#         if "track-audio-path" in track: # We only want audio tracks (many ways to do this, but this is one)
#             track_info = {'track-instrument': track.get('track-instrument', 'Unknown'), 'track-instrument-type': track.get('track-instrument-type', 'Unknown')}
#             parameters = track["parameters"]
#             effects = ['eq', 'gate', 'compression', 'reverb', 'delay', 'flanger', 'phaser', 'chorus']
#             for effect in effects:
#                 track_info[effect] = 1 if effect in parameters else 0
#             tracks_information.append(track_info)

# df_tracks = pd.DataFrame(tracks_information)

# df_tracks.head(50)

# %%
import soundfile as sf
import pyloudnorm as pyln

for mix in mixes: 
    for track in mix:
        if "track-audio-path" in track:
            print(track.get('track-name'))
            data, rate = sf.read("./." + track.get('track-audio-path')) # load audio (with shape (samples, channels))
            meter = pyln.Meter(rate) # create BS.1770 meter
            loudness = meter.integrated_loudness(data) # measure loudness
            print(loudness)

# %%
# Make sure the sample rate is what we expect
import wave
import soundfile as sf

# for index, row in track_list_df.iterrows():
for mix in mixes: 
    for track in mix:
        if "track-audio-path" in track:
            audio_path = '.' + str(track['track-audio-path'])
            data, samplerate = sf.read(audio_path, dtype='float32')
            print(f"Sample rate: {samplerate}")
            print(f"Shape: {data}")
            track['track-audio-sample-rate'] = samplerate
            track['track-audio-data'] = data

# %%
import json

# Load the original tracks.json file
with open('../tracks.json', 'r') as file:
    data = json.load(file)

# Iterate over each track and modify it
for mix in data['mixes']:
    for track in mix['tracks']:
        if "track-audio-path" in track:
            # Create the new 'track-audio-features' dictionary
            track_audio_features = {
                'track-audio-path': track.pop('track-audio-path', None)  # Remove the track-audio-path and get its value
            }
            # Add the 'track-audio-features' dictionary to the track
            track['track-audio-features'] = track_audio_features

# Write the updated data to a new file
with open('../updated_tracks.json', 'w') as file:
    json.dump(data, file, indent=2)

# %%
import json
import soundfile as sf
import pyloudnorm as pyln
import numpy as np
import os

# Load your JSON data
with open('../updated_tracks.json', 'r') as file:
    data = json.load(file)

for mix in data['mixes']:
    for track in mix['tracks']:
        if "track-audio-features" in track:
            # Get the full audio path
            previous_audio_path = str(track['track-audio-features']['track-audio-path'])
            audio_path = '../' + previous_audio_path[2:]

            print(audio_path)
            # Read the audio file to get sample rate and data
            track_data, samplerate = sf.read(audio_path, dtype='float32')

            meter = pyln.Meter(samplerate) # create BS.1770 meter
            loudness = meter.integrated_loudness(track_data) # measure loudness

            name_audio = previous_audio_path[8:len(previous_audio_path)-4] + '.npy'
            name_audio_dir = '../np-arrays/' + name_audio.split('/')[0]
            name_audio_file = '../np-arrays/' + name_audio

            # Create the directory if it doesn't exist
            os.makedirs(name_audio_dir, exist_ok=True)

            # Create the file for the np array
            open(name_audio_file, 'w').close()

            np.save(name_audio_file, track_data)

            print(samplerate, loudness) 
            # Create the new 'track-audio-features' dictionary
            track_audio_features = {
                'track-audio-path': previous_audio_path,
                'track-audio-sample-rate': samplerate,
                'track-audio-data': '../np-arrays/' + name_audio,
                'track-audio-lufs': loudness
            }

            # Add the 'track-audio-features' dictionary to the track
            track['track-audio-features'] = track_audio_features

# Write the updated data to a new file
with open('../updated_tracks_full.json', 'w') as file:
    json.dump(data, file, indent=2)

# print(data)
# Out:
# ../audio/Vermont/01 K in.wav
# 88200 -21.164288599793807
# ../audio/Vermont/02 K out.wav
# 88200 -24.559226110731856
# ../audio/Vermont/03 S top.wav
# 88200 -24.43009887714256
# ../audio/Vermont/04 S bot.wav
# 88200 -26.439228681934114
# ../audio/Vermont/05 R tom.wav
# 88200 -32.554750610519484
# ../audio/Vermont/06 Fl tom.wav
# 88200 -30.82851936045886
# ../audio/Vermont/08 OH ride.wav
# 88200 -24.83936214743081
# ../audio/Vermont/09 OH c.wav
# 88200 -22.998441573792007
# ../audio/Vermont/07 OH hh.wav
# 88200 -23.66046006949744
# ../audio/Vermont/10 Rm hh.wav
# 88200 -18.970095372834596
# ../audio/Vermont/11 Rm ride.wav
# 88200 -17.693618089926552
# ../audio/Vermont/12 Tmbo.wav
# 88200 -28.91695340741545
# ../audio/Vermont/13 Tmbo 2x.wav
# 88200 -26.68405171270473
# ../audio/Vermont/14 B di.wav
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 23
#      20 track_data, samplerate = sf.read(audio_path, dtype='float32')
#      22 meter = pyln.Meter(samplerate) # create BS.1770 meter
# ---> 23 loudness = meter.integrated_loudness(track_data) # measure loudness
#      25 name_audio = previous_audio_path[8:len(previous_audio_path)-4] + '.npy'
#      26 name_audio_dir = '../np-arrays/' + name_audio.split('/')[0]
#
# File ~/Development/MixologyDB/.conda/lib/python3.11/site-packages/pyloudnorm/meter.py:66, in Meter.integrated_loudness(self, data)
#      64 for (filter_class, filter_stage) in iteritems(self._filters):
#      65     for ch in range(numChannels):
# ---> 66         input_data[:,ch] = filter_stage.apply_filter(input_data[:,ch])
#      68 G = [1.0, 1.0, 1.0, 1.41, 1.41] # channel gains
#      69 T_g = self.block_size # 400 ms gating block standard
#
# File ~/Development/MixologyDB/.conda/lib/python3.11/site-packages/pyloudnorm/iirfilter.py:170, in IIRfilter.apply_filter(self, data)
#     157 def apply_filter(self, data):
#     158     """ Apply the IIR filter to an input signal.
#     159
#     160     Params
#    (...)
#     168         Filtered input audio.
#     169     """
# --> 170     return self.passband_gain * scipy.signal.lfilter(self.b, self.a, data)
#
# File ~/Development/MixologyDB/.conda/lib/python3.11/site-packages/scipy/signal/_signaltools.py:2155, in lfilter(b, a, x, axis, zi)
#    2153 else:
#    2154     if zi is None:
# -> 2155         return _sigtools._linear_filter(b, a, x, axis)
#    2156     else:
#    2157         return _sigtools._linear_filter(b, a, x, axis, zi)
#
# KeyboardInterrupt:

# %%
# !pip install ffprobe
# Out:
# Collecting ffprobe
#   Downloading ffprobe-0.5.zip (3.5 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ffprobe
#   Building wheel for ffprobe (setup.py) ... done
#   Created wheel for ffprobe: filename=ffprobe-0.5-py3-none-any.whl size=3406 sha256=7e4d9e534c7b5ba096d418ffb1287a7c0d57f51e80e482fdd203223e3da38bbb
#   Stored in directory: /Users/mclem/Library/Caches/pip/wheels/2c/cb/c1/10daee0c3fad04c9d900006cd0f24bdd47afb74a5c1c085795
# Successfully built ffprobe
# Installing collected packages: ffprobe
# Successfully installed ffprobe-0.5

# %%
import json
import soundfile as sf
import pyloudnorm as pyln
import numpy as np
import os
from pydub import AudioSegment

sample_rate = 0

def detect_silence_lufs(audio_path, silence_threshold=-40.0, chunk_size=2):
    """
    Detects silence at the beginning of an audio file using LUFS.
    
    Parameters:
    - audio_path: Path to the audio file.
    - silence_threshold: Threshold in LUFS for silence detection.
    - chunk_size: Size of audio chunks to analyze.
    
    Returns:
    - start_time: Start time of the first non-silent chunk in seconds.
    """
    track_data, sample_rate = sf.read(audio_path, dtype='float32')
    silence_duration = 0
    start_time = 0
    counter = 0

    for i in range(0, len(track_data), chunk_size * sample_rate):
        chunk = track_data[i:i + chunk_size * sample_rate]
        meter = pyln.Meter(sample_rate) # create BS.1770 meter
        loudness = meter.integrated_loudness(chunk) # measure loudness
    
        if loudness < silence_threshold:
            silence_duration += chunk_size
        else:
            if silence_duration > 0:
                start_time = i / sample_rate
            break

    return start_time

def trim_audio(audio_path, start_time):
    """
    Trims the audio file to start from the specified start time.
    
    Parameters:
    - audio_path: Path to the audio file.
    - start_time: Start time in seconds.
    
    Returns:
    - trimmed_audio: Trimmed audio file.
    """
    audio = AudioSegment.from_wav(audio_path)
    start_time_ms = start_time * 1000  # Convert seconds to milliseconds
    trimmed_audio = audio[start_time_ms:]  # Trim from start_time_ms
    return trimmed_audio


# Load your JSON data
with open('../updated_tracks.json', 'r') as file:
    data = json.load(file)

for mix in data['mixes']:
    for track in mix['tracks']:
        if "track-audio-features" in track:
            # Get the full audio path
            previous_audio_path = str(track['track-audio-features']['track-audio-path'])

            name_audio = previous_audio_path[8:len(previous_audio_path)-4] + '.npy'
            name_audio_dir = '../audio/Truncated/' + name_audio.split('/')[0]
            name_audio_file = '../audio/Truncated/' + previous_audio_path[8:]
            
            print(previous_audio_path)

            # Create the directory if it doesn't exist
            os.makedirs(name_audio_dir, exist_ok=True)
             
            if os.path.exists(name_audio_file):
                continue  # Skip this file if it has been processed
            

            start_time = detect_silence_lufs('.' + previous_audio_path)
            print("Start time:", start_time)
            
            # print(previous_audio_path[len(previous_audio_path)-3:])

            trimmed_audio = trim_audio('.' + previous_audio_path, start_time)
            trimmed_audio.export(name_audio_file, format=previous_audio_path[len(previous_audio_path)-3:])
# Out:
# ./audio/Vermont/01 K in.wav
# ./audio/Vermont/02 K out.wav
# ./audio/Vermont/03 S top.wav
# ./audio/Vermont/04 S bot.wav
# ./audio/Vermont/05 R tom.wav
# ./audio/Vermont/06 Fl tom.wav
# ./audio/Vermont/08 OH ride.wav
# ./audio/Vermont/09 OH c.wav
# ./audio/Vermont/07 OH hh.wav
# ./audio/Vermont/10 Rm hh.wav
# ./audio/Vermont/11 Rm ride.wav
# ./audio/Vermont/12 Tmbo.wav
# ./audio/Vermont/13 Tmbo 2x.wav
# ./audio/Vermont/14 B di.wav
# ./audio/Vermont/18 mGtr1.wav
# ./audio/Vermont/20 mGtr rm.wav
# ./audio/Vermont/21 rGtr1.wav
# ./audio/Vermont/22 rGtr2 rm.wav
# ./audio/Vermont/22 rGtr2 rm.wav
# ./audio/Vermont/23 rGtr3.wav
# ./audio/Vermont/23 rGtr3 rm.wav
# ./audio/Vermont/26 mVHmy1.wav
# ./audio/Vermont/27 rVHmy1.wav
# ./audio/Vermont/16 Wrlz hi.wav
# ./audio/Vermont/17 Wrlz lo.wav
# ./audio/Vermont/24 rV1.wav
# ./audio/Vermont/25 rV1 2x.wav
# ./audio/Vermont/24 rV1.wav
# ./audio/Vermont/25 rV1 2x.wav
# ./audio/Vermont/24 rV1.wav
# ./audio/Vermont/01 K in.wav
# ./audio/Vermont/03 S top.wav
# ./audio/Vermont/04 S bot.wav
# ./audio/Vermont/05 R tom.wav
# ./audio/Vermont/06 Fl tom.wav
# ./audio/Vermont/07 OH hh.wav
201 CONS.wav
# ./audio/UnderACoveredSky/HGtr2-84 CONS.wav
# ./audio/UnderACoveredSky/Keys CONS.wav
# ./audio/UnderACoveredSky/Kin CONS.wav
# ./audio/UnderACoveredSky/KOut CONS.wav
# ./audio/UnderACoveredSky/SnT2 CONS.wav
# ./audio/UnderACoveredSky/StOH CONS.wav
# ./audio/UnderACoveredSky/Hat CONS.wav
# ./audio/UnderACoveredSky/Tom1 CONS.wav
# ./audio/UnderACoveredSky/Floor CONS.wav
# ./audio/UnderACoveredSky/BassDI CONS.wav
# ./audio/UnderACoveredSky/AGuitCmp CONS.wav
# ./audio/UnderACoveredSky/PaulEGtr201 CONS.wav
# ./audio/UnderACoveredSky/PaulEGtrR84 CONS.wav
# ./audio/UnderACoveredSky/HGtr1-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr1-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr2-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr2-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr3-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr3-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr4-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr4-84 CONS.wav
# ./audio/UnderACoveredSky/Keys CONS.wav
# ./audio/UnderACoveredSky/Keys CONS.R.wav
# ./audio/UnderACoveredSky/LDVoc147C1 CONS.wav
# ./audio/UnderACoveredSky/LDVocChDbl2 CONS.wav
# ./audio/UnderACoveredSky/LDVocVrsDbl1 CONS.wav
# ./audio/UnderACoveredSky/LDVocVrsDbl2 CONS.wav
# ./audio/UnderACoveredSky/LDVocVmpDbl1-58 CONS.wav
# ./audio/UnderACoveredSky/LDVocVmpDbl1-147 CONS.wav
# ./audio/UnderACoveredSky/LDVoc147C1 CONS.wav
# ./audio/UnderACoveredSky/LDVocChDbl1 CONS.wav
# ./audio/UnderACoveredSky/LDVocChDbl2 CONS.wav
# ./audio/UnderACoveredSky/LDVocVrsDbl1 CONS.wav
# ./audio/UnderACoveredSky/LDVocVrsDbl2 CONS.wav
# ./audio/UnderACoveredSky/LDVocVmpDbl1-58 CONS.wav
# ./audio/UnderACoveredSky/LDVocVmpDbl1-147 CONS.wav
# ./audio/UnderACoveredSky/Kin CONS.wav
# ./audio/UnderACoveredSky/KOut CONS.wav
# ./audio/UnderACoveredSky/SnT2 CONS.wav
# ./audio/UnderACoveredSky/StOH CONS.wav
# ./audio/UnderACoveredSky/Hat CONS.wav
# ./audio/UnderACoveredSky/Tom1 CONS.wav
# ./audio/UnderACoveredSky/Floor CONS.wav
# ./audio/UnderACoveredSky/BassDI CONS.wav
# ./audio/UnderACoveredSky/PaulEGtrR84 CONS.wav
# ./audio/UnderACoveredSky/PaulEGtr201 CONS.wav
# ./audio/UnderACoveredSky/Keys CONS.wav
# ./audio/UnderACoveredSky/Keys CONS.R.wav
# ./audio/UnderACoveredSky/HGtr1-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr1-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr2-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr2-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr3-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr3-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr4-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr4-84 CONS.wav
# ./audio/UnderACoveredSky/AGuitCmp CONS.wav
# ./audio/UnderACoveredSky/LDVoc147C1 CONS.wav
# ./audio/UnderACoveredSky/LDVocChDbl1 CONS.wav
# ./audio/UnderACoveredSky/LDVocVrsDbl2 CONS.wav
# ./audio/UnderACoveredSky/LDVocVmpDbl1-147 CONS.wav
# ./audio/UnderACoveredSky/KOut CONS.wav
# ./audio/UnderACoveredSky/SnT2 CONS.wav
# ./audio/UnderACoveredSky/SnT2 CONS.wav
# ./audio/UnderACoveredSky/StOH CONS.wav
# ./audio/UnderACoveredSky/Hat CONS.wav
# ./audio/UnderACoveredSky/Tom1 CONS.wav
# ./audio/UnderACoveredSky/Floor CONS.wav
# ./audio/UnderACoveredSky/BassDI CONS.wav
# ./audio/UnderACoveredSky/AGuitCmp CONS.wav
# ./audio/UnderACoveredSky/PaulEGtrR84 CONS.wav
# ./audio/UnderACoveredSky/PaulEGtr201 CONS.wav
# ./audio/UnderACoveredSky/HGtr1-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr2-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr3-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr4-201 CONS.wav
# ./audio/UnderACoveredSky/Keys CONS.wav
# ./audio/UnderACoveredSky/Keys CONS.wav
# ./audio/UnderACoveredSky/Kin CONS.wav
# ./audio/UnderACoveredSky/KOut CONS.wav
# ./audio/UnderACoveredSky/StOH CONS.wav
# ./audio/UnderACoveredSky/Hat CONS.wav
# ./audio/UnderACoveredSky/Tom1 CONS.wav
# ./audio/UnderACoveredSky/Floor CONS.wav
# ./audio/UnderACoveredSky/BassDI CONS.wav
# ./audio/UnderACoveredSky/AGuitCmp CONS.wav
# ./audio/UnderACoveredSky/PaulEGtr201 CONS.wav
# ./audio/UnderACoveredSky/PaulEGtrR84 CONS.wav
# ./audio/UnderACoveredSky/HGtr1-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr1-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr2-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr2-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr3-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr4-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr4-84 CONS.wav
# ./audio/UnderACoveredSky/Keys CONS.wav
# ./audio/UnderACoveredSky/Keys CONS.wav
# ./audio/UnderACoveredSky/LDVoc147C1 CONS.wav
# ./audio/UnderACoveredSky/LDVocChDbl1 CONS.wav
# ./audio/UnderACoveredSky/LDVocChDbl2 CONS.wav
# ./audio/UnderACoveredSky/LDVocVrsDbl2 CONS.wav
# ./audio/UnderACoveredSky/LDVocVmpDbl1-58 CONS.wav
# ./audio/UnderACoveredSky/LDVocVmpDbl1-147 CONS.wav
# ./audio/UnderACoveredSky/Kin CONS.wav
# ./audio/UnderACoveredSky/KOut CONS.wav
# ./audio/UnderACoveredSky/SnT1 CONS.wav
# ./audio/UnderACoveredSky/SnT2 CONS.wav
# ./audio/UnderACoveredSky/StOH CONS.wav
# ./audio/UnderACoveredSky/Hat CONS.wav
# ./audio/UnderACoveredSky/Tom1 CONS.wav
# ./audio/UnderACoveredSky/Floor CONS.wav
# ./audio/UnderACoveredSky/BassDI CONS.wav
# ./audio/UnderACoveredSky/AGuitCmp CONS.wav
# ./audio/UnderACoveredSky/PaulEGtr201 CONS.wav
# ./audio/UnderACoveredSky/PaulEGtrR84 CONS.wav
# ./audio/UnderACoveredSky/HGtr1-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr1-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr2-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr2-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr3-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr3-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr4-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr4-84 CONS.wav
# ./audio/UnderACoveredSky/Keys CONS.wav
# ./audio/UnderACoveredSky/LDVocChDbl1 CONS.wav
# ./audio/UnderACoveredSky/LDVocChDbl2 CONS.wav
# ./audio/UnderACoveredSky/LDVocVrsDbl1 CONS.wav
# ./audio/UnderACoveredSky/LDVocVrsDbl2 CONS.wav
# ./audio/UnderACoveredSky/LDVocVmpDbl1-58 CONS.wav
# ./audio/UnderACoveredSky/LDVocVmpDbl1-147 CONS.wav
# ./audio/UnderACoveredSky/Kin CONS.wav
# ./audio/UnderACoveredSky/KOut CONS.wav
# ./audio/UnderACoveredSky/SnT2 CONS.wav
# ./audio/UnderACoveredSky/StOH CONS.wav
# ./audio/UnderACoveredSky/Hat CONS.wav
# ./audio/UnderACoveredSky/Tom1 CONS.wav
# ./audio/UnderACoveredSky/Floor CONS.wav
# ./audio/UnderACoveredSky/BassDI CONS.wav
# ./audio/UnderACoveredSky/AGuitCmp CONS.wav
# ./audio/UnderACoveredSky/PaulEGtr201 CONS.wav
# ./audio/UnderACoveredSky/PaulEGtrR84 CONS.wav
# ./audio/UnderACoveredSky/HGtr1-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr1-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr2-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr2-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr3-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr3-84 CONS.wav
# ./audio/UnderACoveredSky/HGtr4-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr4-84 CONS.wav
# ./audio/UnderACoveredSky/Keys CONS.wav
# ./audio/UnderACoveredSky/LDVoc147C1 CONS.wav
# ./audio/UnderACoveredSky/LDVoc147C1 CONS.wav
# ./audio/UnderACoveredSky/LDVocChDbl1 CONS.wav
# ./audio/UnderACoveredSky/LDVocChDbl2 CONS.wav
# ./audio/UnderACoveredSky/LDVocVrsDbl1 CONS.wav
# ./audio/UnderACoveredSky/LDVocVrsDbl2 CONS.wav
# ./audio/UnderACoveredSky/LDVocVmpDbl1-58 CONS.wav
# ./audio/UnderACoveredSky/LDVocVmpDbl1-147 CONS.wav
# ./audio/UnderACoveredSky/Kin CONS.wav
# ./audio/UnderACoveredSky/KOut CONS.wav
# ./audio/UnderACoveredSky/SnT2 CONS.wav
# ./audio/UnderACoveredSky/StOH CONS.wav
# ./audio/UnderACoveredSky/Hat CONS.wav
# ./audio/UnderACoveredSky/Tom1 CONS.wav
# ./audio/UnderACoveredSky/Floor CONS.wav
# ./audio/UnderACoveredSky/BassDI CONS.wav
# ./audio/UnderACoveredSky/AGuitCmp CONS.wav
# ./audio/UnderACoveredSky/PaulEGtrR84 CONS.wav
# ./audio/UnderACoveredSky/HGtr1-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr2-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr3-201 CONS.wav
# ./audio/UnderACoveredSky/HGtr4-201 CONS.wav
# ./audio/UnderACoveredSky/Keys CONS.wav
# ./audio/UnderACoveredSky/LDVoc147C1 CONS.wav
# ./audio/UnderACoveredSky/LDVocChDbl1 CONS.wav
# ./audio/UnderACoveredSky/LDVocChDbl2 CONS.wav
# ./audio/UnderACoveredSky/LDVoc147C1 CONS.wav
# ./audio/UnderACoveredSky/LDVocVmpDbl1-58 CONS.wav
# ./audio/LeadMe/Kout.wav
# ./audio/LeadMe/SnT2.wav
# ./audio/LeadMe/StOH.wav
# ./audio/LeadMe/Hat.wav
# ./audio/LeadMe/Tom1.wav
# ./audio/LeadMe/Snaps1.wav
# ./audio/LeadMe/Floor.wav
# ./audio/LeadMe/Act Guit.wav
# ./audio/LeadMe/Paul GTR.wav
# ./audio/LeadMe/Paul GTR.double.wav
# ./audio/LeadMe/Keys2 (edit).wav
# ./audio/LeadMe/Accordian (edit).wav
# ./audio/LeadMe/JanineVoc.wav
# ./audio/LeadMe/GangM1.wav
# ./audio/LeadMe/GangM2.wav
# ./audio/LeadMe/GangM3.wav
# ./audio/LeadMe/GangM4.wav
# ./audio/LeadMe/LeadVoc.wav
# ./audio/LeadMe/Bass DI.wav
# ./audio/LeadMe/Act Guit.wav
# ./audio/LeadMe/KOut.wav
# ./audio/LeadMe/Kin.wav
# ./audio/LeadMe/SnT1.wav
# ./audio/LeadMe/SnT2.wav
# ./audio/LeadMe/StOH.wav
# ./audio/LeadMe/Tom1.wav
# ./audio/LeadMe/Kin.wav
# ./audio/LeadMe/KOut.wav
# ./audio/LeadMe/SnT1.wav
# ./audio/LeadMe/SnT2.wav
# ./audio/LeadMe/StOH.wav
# ./audio/LeadMe/Hat.wav
# ./audio/LeadMe/Tom1.wav
# ./audio/LeadMe/Floor.wav
# ./audio/LeadMe/Snaps1.wav
# ./audio/LeadMe/Bass DI.wav
# ./audio/LeadMe/Act Guit.wav
# ./audio/LeadMe/Ac Guit DI.wav
# ./audio/LeadMe/Keys2 (edit).wav
# ./audio/LeadMe/Accordian (edit).wav
# ./audio/LeadMe/LeadVoc.wav
# ./audio/LeadMe/JanineVoc.wav
# ./audio/LeadMe/GangM1.wav
# ./audio/LeadMe/GangM2.wav
# ./audio/LeadMe/GangM3.wav
# ./audio/LeadMe/GangM4.wav
# ./audio/LeadMe/Kin.wav
# ./audio/LeadMe/KOut.wav
# ./audio/LeadMe/SnT1.wav
# ./audio/LeadMe/StOH.wav
# ./audio/LeadMe/Hat.wav
# ./audio/LeadMe/Tom1.wav
# ./audio/LeadMe/Floor.wav
# ./audio/LeadMe/Snaps1.wav
# ./audio/LeadMe/Bass DI.wav
# ./audio/LeadMe/Act Guit.wav
# ./audio/LeadMe/Ac Guit DI.wav
# ./audio/LeadMe/Paul GTR.wav
# ./audio/LeadMe/Paul GTR.double.wav
# ./audio/LeadMe/Keys2 (edit).wav
# ./audio/LeadMe/Accordian (edit).wav
# ./audio/LeadMe/LeadVoc.wav
# ./audio/LeadMe/JanineVoc.wav
# ./audio/LeadMe/GangM1.wav
# ./audio/LeadMe/GangM2.wav
# ./audio/LeadMe/GangM3.wav
# ./audio/LeadMe/GangM4.wav
# ./audio/LeadMe/Kin.wav
# ./audio/LeadMe/KOut.wav
# ./audio/LeadMe/SnT2.wav
# ./audio/LeadMe/StOH.wav
# ./audio/LeadMe/Hat.wav
# ./audio/LeadMe/Tom1.wav
# ./audio/LeadMe/Floor.wav
# ./audio/LeadMe/Snaps1.wav
# ./audio/LeadMe/Bass DI.wav
# ./audio/LeadMe/Act Guit.wav
# ./audio/LeadMe/Paul GTR.wav
# ./audio/LeadMe/Paul GTR R84.wav
# ./audio/LeadMe/Paul GTR.double.wav
# ./audio/LeadMe/Keys2 (edit).wav
# ./audio/LeadMe/Accordian (edit).wav
# ./audio/LeadMe/LeadVoc.wav
# ./audio/LeadMe/JanineVoc.wav
# ./audio/LeadMe/GangM1.wav
# ./audio/LeadMe/GangM2.wav
# ./audio/LeadMe/GangM3.wav
# ./audio/LeadMe/GangM4.wav
# ./audio/LeadMe/Kin.wav
# ./audio/LeadMe/KOut.wav
# ./audio/LeadMe/SnT1.wav
# ./audio/LeadMe/SnT2.wav
# ./audio/LeadMe/StOH.wav
# ./audio/LeadMe/Hat.wav
# ./audio/LeadMe/Tom1.wav
# ./audio/LeadMe/Floor.wav
# ./audio/LeadMe/Snaps1.wav
# ./audio/LeadMe/Bass DI.wav
# ./audio/LeadMe/Act Guit.wav
# ./audio/LeadMe/Ac Guit DI.wav
# ./audio/LeadMe/Paul GTR.wav
# ./audio/LeadMe/Paul GTR R84.wav
# ./audio/LeadMe/Paul GTR.double.wav
# ./audio/LeadMe/Keys2 (edit).wav
# ./audio/LeadMe/Accordian (edit).wav
# ./audio/LeadMe/LeadVoc.wav
# ./audio/LeadMe/JanineVoc.wav
# ./audio/LeadMe/GangM1.wav
# ./audio/LeadMe/GangM2.wav
# ./audio/LeadMe/GangM3.wav
# ./audio/LeadMe/GangM4.wav
# ./audio/LeadMe/Kin.wav
# ./audio/LeadMe/KOut.wav
# ./audio/LeadMe/SnT1.wav
# ./audio/LeadMe/SnT2.wav
# ./audio/LeadMe/StOH.wav
# ./audio/LeadMe/Hat.wav
# ./audio/LeadMe/Tom1.wav
# ./audio/LeadMe/Floor.wav
# ./audio/LeadMe/Snaps1.wav
# ./audio/LeadMe/Bass DI.wav
# ./audio/LeadMe/Act Guit.wav
# ./audio/LeadMe/Ac Guit DI.wav
# ./audio/LeadMe/Paul GTR.wav
# ./audio/LeadMe/Paul GTR R84.wav
# ./audio/LeadMe/Keys2 (edit).wav
# ./audio/LeadMe/Accordian (edit).wav
# ./audio/LeadMe/LeadVoc.wav
# ./audio/LeadMe/JanineVoc.wav
# ./audio/LeadMe/GangM1.wav
# ./audio/LeadMe/GangM2.wav
# ./audio/LeadMe/GangM3.wav
# ./audio/LeadMe/GangM4.wav
# ./audio/LeadMe/Kin.wav
# ./audio/LeadMe/KOut.wav
# ./audio/LeadMe/SnT2.wav
# ./audio/LeadMe/StOH.wav
# ./audio/LeadMe/Hat.wav
# ./audio/LeadMe/Tom1.wav
# ./audio/LeadMe/Floor.wav
# ./audio/LeadMe/Paul GTR.wav
# ./audio/LeadMe/Paul GTR R84.wav
# ./audio/LeadMe/Paul GTR.double.wav
# ./audio/LeadMe/GangM1.wav
# ./audio/LeadMe/GangM2.wav
# ./audio/LeadMe/GangM3.wav
# ./audio/LeadMe/GangM4.wav
# ./audio/LeadMe/Snaps1.wav
# ./audio/LeadMe/Bass DI.wav
# ./audio/LeadMe/Keys2 (edit).wav
# ./audio/LeadMe/Accordian (edit).wav
# ./audio/LeadMe/Act Guit.wav
# ./audio/LeadMe/LeadVoc.wav
# ./audio/LeadMe/JanineVoc.wav
# ./audio/LeadMe/JanineVoc.wav
# ./audio/LeadMe/LeadVoc.wav
# ./audio/LeadMe/GangM1.wav
# ./audio/LeadMe/GangM2.wav
# ./audio/LeadMe/GangM3.wav
# ./audio/LeadMe/GangM4.wav
# ./audio/LeadMe/Ac Guit DI.wav
# ./audio/LeadMe/Act Guit.wav
# ./audio/LeadMe/Paul GTR.wav
# ./audio/LeadMe/Paul GTR.double.wav
# ./audio/LeadMe/Paul GTR R84.wav
# ./audio/LeadMe/Accordian (edit).wav
# ./audio/LeadMe/Bass DI.wav
# ./audio/LeadMe/Keys2 (edit).wav
# ./audio/LeadMe/SnT1.wav
# ./audio/LeadMe/SnT2.wav
# ./audio/LeadMe/StOH.wav
# ./audio/LeadMe/Floor.wav
# ./audio/LeadMe/Tom1.wav
# ./audio/LeadMe/Hat.wav
# ./audio/LeadMe/KOut.wav
# ./audio/LeadMe/Kin.wav
# ./audio/LeadMe/LeadVoc.wav
# ./audio/LeadMe/JanineVoc.wav
# ./audio/LeadMe/GangM1.wav
# ./audio/LeadMe/GangM2.wav
# ./audio/LeadMe/GangM3.wav
# ./audio/LeadMe/GangM4.wav
# ./audio/LeadMe/Act Guit.wav
# ./audio/LeadMe/Ac Guit DI.wav
# ./audio/LeadMe/Paul GTR.wav
# ./audio/LeadMe/Paul GTR R84.wav
# ./audio/LeadMe/Paul GTR.double.wav
# ./audio/LeadMe/Keys2 (edit).wav
# ./audio/LeadMe/Bass DI.wav
# ./audio/LeadMe/KOut.wav
# ./audio/LeadMe/Kin.wav
# ./audio/LeadMe/SnT1.wav
# ./audio/LeadMe/SnT2.wav
# ./audio/LeadMe/Hat.wav
# ./audio/LeadMe/Tom1.wav
# ./audio/LeadMe/Floor.wav
# ./audio/LeadMe/StOH.wav
# ./audio/LeadMe/Snaps1.wav
# ./audio/LeadMe/LeadVoc.wav
# ./audio/LeadMe/JanineVoc.wav
# ./audio/LeadMe/GangM1.wav
# ./audio/LeadMe/GangM2.wav
# ./audio/LeadMe/GangM3.wav
# ./audio/LeadMe/GangM4.wav
# ./audio/LeadMe/Ac Guit DI.wav
# ./audio/LeadMe/Act Guit.wav
# ./audio/LeadMe/Paul GTR.wav
# ./audio/LeadMe/Paul GTR R84.wav
# ./audio/LeadMe/Paul GTR.double.wav
# ./audio/LeadMe/Accordian (edit).wav
# ./audio/LeadMe/Keys2 (edit).wav
# ./audio/LeadMe/Bass DI.wav
# ./audio/LeadMe/Kin.wav
# ./audio/LeadMe/KOut.wav
# ./audio/LeadMe/SnT1.wav
# ./audio/LeadMe/SnT2.wav
# ./audio/LeadMe/Floor.wav
# ./audio/LeadMe/Tom1.wav
# ./audio/LeadMe/Hat.wav
# ./audio/LeadMe/StOH.wav
# ./audio/LeadMe/Snaps1.wav
# ./audio/LeadMe/KOut.wav
# ./audio/LeadMe/Kin.wav
# ...
# ./audio/RedToBlue/GTR 2.02_01.wav
# ./audio/RedToBlue/Gtr 3.03_01.wav
# ./audio/RedToBlue/Guitar 04_02.wav
# ./audio/RedToBlue/Guitar 05.02_01.wav
# ./audio/RedToBlue/Guitar 06_03.wav
# ./audio/RedToBlue/Leslie gtr.wav
# ./audio/RedToBlue/Slide Guitar.wav
# ./audio/RedToBlue/SoloGtr.wav
# ./audio/RedToBlue/Ac GTR.wav
# ./audio/RedToBlue/Ac hi dbl.wav
# ./audio/RedToBlue/Hmnd.wav
# ./audio/RedToBlue/Hmnd.wav
# ./audio/RedToBlue/VOX.wav
# ./audio/RedToBlue/John Double.wav
# ./audio/RedToBlue/VOXLeslie.01_08.wav
# ./audio/RedToBlue/John Hi_01 L.wav
# ./audio/RedToBlue/John Hi_01 R.wav
# ./audio/RedToBlue/Bop 01_06.wav
# ./audio/RedToBlue/Bop 02_05.wav
# ./audio/RedToBlue/Bop 03_04.wav
# ./audio/RedToBlue/VOX Double 01.dup1_04.wav
# ./audio/RedToBlue/VOX Double 01.dup2_02.wav
# ./audio/RedToBlue/VOX Back 01_05.wav
# ./audio/RedToBlue/VOX Back 01.dup1_12.wav
# ./audio/RedToBlue/VOX Back 01.dup2_10.wav
# ./audio/RedToBlue/VOX Back 03_09.wav
# ./audio/RedToBlue/VOX Back 04_20.wav
# ./audio/RedToBlue/VOX Back 05_10.wav
# ./audio/RedToBlue/VOXVamp.03_01.wav
# ./audio/RedToBlue/OH L.wav
# ./audio/RedToBlue/Oh R.wav
# ./audio/RedToBlue/Kick.wav
# ./audio/RedToBlue/Snare.wav
# ./audio/RedToBlue/Tom 1.wav
# ./audio/RedToBlue/Tom 2.wav
# ./audio/RedToBlue/Flr Tom.wav
# ./audio/RedToBlue/Room1 L.wav
# ./audio/RedToBlue/Room1 R.wav
# ./audio/RedToBlue/Room2 L.wav
# ./audio/RedToBlue/Room2 R.wav
# ./audio/RedToBlue/Bass.wav
# ./audio/RedToBlue/GTR.09_01.wav
# ./audio/RedToBlue/GTR 1 OD.05_01.wav
# ./audio/RedToBlue/GTR 2.02_01.wav
# ./audio/RedToBlue/Guitar 05.02_01.wav
# ./audio/RedToBlue/Guitar 06_03.wav
# ./audio/RedToBlue/Gtr 3.03_01.wav
# ./audio/RedToBlue/Leslie gtr.wav
# ./audio/RedToBlue/Slide Guitar.wav
# ./audio/RedToBlue/SoloGtr.wav
# ./audio/RedToBlue/Ac GTR.wav
# ./audio/RedToBlue/Ac hi dbl.wav
# ./audio/RedToBlue/Hmnd.wav
# ./audio/RedToBlue/Tamb.wav
# ./audio/RedToBlue/VOX.wav
# ./audio/RedToBlue/John Double.wav
# ./audio/RedToBlue/VOXLeslie.01_08.wav
# ./audio/RedToBlue/VOXVamp.03_01.wav
# ./audio/RedToBlue/VOX Back 01.dup2_10.wav
# ./audio/RedToBlue/VOX Back 03_09.wav
# ./audio/RedToBlue/VOX Back 04_20.wav
# ./audio/RedToBlue/VOX Back 05_10.wav
# ./audio/RedToBlue/John Hi_01 L.wav
# ./audio/RedToBlue/John Hi_01 R.wav
# ./audio/RedToBlue/VOX Double 01.dup1_04.wav
# ./audio/RedToBlue/VOX Double 01.dup2_02.wav
# ./audio/RedToBlue/VOX Back 01_05.wav
# ./audio/RedToBlue/Bop 01_06.wav
# ./audio/RedToBlue/Bop 02_05.wav
# ./audio/RedToBlue/Bop 03_04.wav
# ./audio/RedToBlue/Kick.wav
# ./audio/RedToBlue/Snare.wav
# ./audio/RedToBlue/Flr Tom.wav
# ./audio/RedToBlue/Tom 2.wav
# ./audio/RedToBlue/Tom 1.wav
# ./audio/RedToBlue/OH L.wav
# ./audio/RedToBlue/Oh R.wav
# ./audio/RedToBlue/Room2 L.wav
# ./audio/RedToBlue/Room2 R.wav
# ./audio/RedToBlue/Tamb.wav
# ./audio/RedToBlue/Bass.wav
# ./audio/RedToBlue/GTR.09_01.wav
# ./audio/RedToBlue/GTR 1 OD.05_01.wav
# ./audio/RedToBlue/GTR 2.02_01.wav
# ./audio/RedToBlue/Gtr 3.03_01.wav
# ./audio/RedToBlue/Guitar 04_02.wav
# ./audio/RedToBlue/Guitar 05.02_01.wav
# ./audio/RedToBlue/Guitar 06_03.wav
# ./audio/RedToBlue/Leslie gtr.wav
# ./audio/RedToBlue/Slide Guitar.wav
# ./audio/RedToBlue/SoloGtr.wav
# ./audio/RedToBlue/Ac GTR.wav
# ./audio/RedToBlue/Ac hi dbl.wav
# ./audio/RedToBlue/Hmnd.wav
# ./audio/RedToBlue/VOX.wav
# ./audio/RedToBlue/VOX Double 01.dup2_02.wav
# ./audio/RedToBlue/John Hi_01 L.wav
# ./audio/RedToBlue/John Hi_01 R.wav
# ./audio/RedToBlue/Bop 01_06.wav
# ./audio/RedToBlue/Bop 02_05.wav
# ./audio/RedToBlue/Bop 03_04.wav
# ./audio/RedToBlue/VOX Double 01.dup1_04.wav
# ./audio/RedToBlue/VOX Double 01.dup2_02.wav
# ./audio/RedToBlue/VOX Back 01_05.wav
# ./audio/RedToBlue/VOX Back 01.dup1_12.wav
# ./audio/RedToBlue/VOX Back 01.dup2_10.wav
# ./audio/RedToBlue/VOX Back 03_09.wav
# ./audio/RedToBlue/VOX Back 04_20.wav
# ./audio/RedToBlue/VOX Back 05_10.wav
# ./audio/RedToBlue/Leslie gtr.wav
# ./audio/RedToBlue/VOXVamp.03_01.wav
# ./audio/RedToBlue/Kick.wav
# ./audio/RedToBlue/Snare.wav
# ./audio/RedToBlue/OH L.wav
# ./audio/RedToBlue/Oh R.wav
# ./audio/RedToBlue/Flr Tom.wav
# ./audio/RedToBlue/Tom 2.wav
# ./audio/RedToBlue/Tom 1.wav
# ./audio/RedToBlue/Room1 L.wav
# ./audio/RedToBlue/Room1 R.wav
# ./audio/RedToBlue/Room2 L.wav
# ./audio/RedToBlue/Room2 R.wav
# ./audio/RedToBlue/Tamb.wav
# ./audio/RedToBlue/Bass.wav
# ./audio/RedToBlue/GTR.09_01.wav
# ./audio/RedToBlue/GTR 2.02_01.wav
# ./audio/RedToBlue/GTR 1 OD.05_01.wav
# ./audio/RedToBlue/Guitar 04_02.wav
# ./audio/RedToBlue/Gtr 3.03_01.wav
# ./audio/RedToBlue/Guitar 05.02_01.wav
# ./audio/RedToBlue/Guitar 06_03.wav
# ./audio/RedToBlue/Slide Guitar.wav
# ./audio/RedToBlue/Leslie gtr.wav
# ./audio/RedToBlue/SoloGtr.wav
# ./audio/RedToBlue/Ac GTR.wav
# ./audio/RedToBlue/Ac hi dbl.wav
# ./audio/RedToBlue/Hmnd.wav
# ./audio/RedToBlue/VOX.wav
# ./audio/RedToBlue/VOXLeslie.01_08.wav
# ./audio/RedToBlue/VOXVamp.03_01.wav
# ./audio/RedToBlue/John Double.wav
# ./audio/RedToBlue/John Hi_01 L.wav
# ./audio/RedToBlue/John Hi_01 R.wav
# ./audio/RedToBlue/Bop 01_06.wav
# ./audio/RedToBlue/Bop 02_05.wav
# ./audio/RedToBlue/Bop 03_04.wav
# ./audio/RedToBlue/VOX Double 01.dup1_04.wav
# ./audio/RedToBlue/VOX Double 01.dup2_02.wav
# ./audio/RedToBlue/VOX Back 01_05.wav
# ./audio/RedToBlue/VOX Back 01.dup1_12.wav
# ./audio/RedToBlue/VOX Back 01.dup2_10.wav
# ./audio/RedToBlue/VOX Back 03_09.wav
# ./audio/RedToBlue/VOX Back 04_20.wav
# ./audio/RedToBlue/VOX Back 05_10.wav
# ./audio/RedToBlue/Kick.wav
# ./audio/RedToBlue/Snare.wav
# ./audio/RedToBlue/OH L.wav
# ./audio/RedToBlue/Oh R.wav
# ./audio/RedToBlue/Flr Tom.wav
# ./audio/RedToBlue/Tom 2.wav
# ./audio/RedToBlue/Tom 1.wav
# ./audio/RedToBlue/Room1 L.wav
# ./audio/RedToBlue/Room1 R.wav
# ./audio/RedToBlue/Room2 L.wav
# ./audio/RedToBlue/Room2 R.wav
# ./audio/RedToBlue/Tamb.wav
# ./audio/RedToBlue/Bass.wav
# ./audio/RedToBlue/GTR.09_01.wav
# ./audio/RedToBlue/GTR 1 OD.05_01.wav
# ./audio/RedToBlue/GTR 2.02_01.wav
# ./audio/RedToBlue/Gtr 3.03_01.wav
# ./audio/RedToBlue/Guitar 04_02.wav
# ./audio/RedToBlue/Guitar 05.02_01.wav
# ./audio/RedToBlue/Guitar 06_03.wav
# ./audio/RedToBlue/Leslie gtr.wav
# ./audio/RedToBlue/Slide Guitar.wav
# ./audio/RedToBlue/SoloGtr.wav
# ./audio/RedToBlue/Ac GTR.wav
# ./audio/RedToBlue/Ac hi dbl.wav
# ./audio/RedToBlue/Hmnd.wav
# ./audio/RedToBlue/Hmnd.wav
# ./audio/RedToBlue/VOX.wav
# ./audio/RedToBlue/John Double.wav
# ./audio/RedToBlue/John Hi_01 L.wav
# ./audio/RedToBlue/John Hi_01 R.wav
# ./audio/RedToBlue/Bop 01_06.wav
# ./audio/RedToBlue/Bop 02_05.wav
# ./audio/RedToBlue/Bop 03_04.wav
# ./audio/RedToBlue/VOX Double 01.dup1_04.wav
# ./audio/RedToBlue/VOX Double 01.dup2_02.wav
# ./audio/RedToBlue/VOX Back 01_05.wav
# ./audio/RedToBlue/VOX Back 01.dup1_12.wav
# ./audio/RedToBlue/VOX Back 01.dup2_10.wav
# ./audio/RedToBlue/VOX Back 03_09.wav
# ./audio/RedToBlue/VOX Back 04_20.wav
# ./audio/RedToBlue/VOX Back 05_10.wav
# ./audio/RedToBlue/VOXLeslie.01_08.wav
# ./audio/RedToBlue/VOXVamp.03_01.wav
# ./audio/RedToBlue/Kick.wav
# ./audio/RedToBlue/Snare.wav
# ./audio/RedToBlue/OH L.wav
# ./audio/RedToBlue/Oh R.wav
# ./audio/RedToBlue/Tom 1.wav
# ./audio/RedToBlue/Tom 2.wav
# ./audio/RedToBlue/Flr Tom.wav
# ./audio/RedToBlue/Room1 L.wav
# ./audio/RedToBlue/Room1 R.wav
# ./audio/RedToBlue/Room2 L.wav
# ./audio/RedToBlue/Room2 R.wav
# ./audio/RedToBlue/Tamb.wav
# ./audio/RedToBlue/Bass.wav
# ./audio/RedToBlue/GTR.09_01.wav
# ./audio/RedToBlue/GTR 1 OD.05_01.wav
# ./audio/RedToBlue/GTR 2.02_01.wav
# ./audio/RedToBlue/Gtr 3.03_01.wav
# ./audio/RedToBlue/Guitar 04_02.wav
# ./audio/RedToBlue/Guitar 05.02_01.wav
# ./audio/RedToBlue/Guitar 06_03.wav
# ./audio/RedToBlue/Leslie gtr.wav
# ./audio/RedToBlue/Slide Guitar.wav
# ./audio/RedToBlue/SoloGtr.wav
# ./audio/RedToBlue/Ac GTR.wav
# ./audio/RedToBlue/Ac hi dbl.wav
# ./audio/RedToBlue/Hmnd.wav
# ./audio/RedToBlue/VOX.wav
# ./audio/RedToBlue/John Double.wav
# ./audio/RedToBlue/John Hi_01 L.wav
# ./audio/RedToBlue/John Hi_01 R.wav
# ./audio/RedToBlue/Bop 01_06.wav
# ./audio/RedToBlue/Bop 02_05.wav
# ./audio/RedToBlue/Bop 03_04.wav
# ./audio/RedToBlue/VOX Double 01.dup1_04.wav
# ./audio/RedToBlue/VOX Double 01.dup2_02.wav
# ./audio/RedToBlue/VOX Back 01_05.wav
# ./audio/RedToBlue/VOX Back 01.dup1_12.wav
# ./audio/RedToBlue/VOX Back 01.dup2_10.wav
# ./audio/RedToBlue/VOX Back 03_09.wav
# ./audio/RedToBlue/VOX Back 04_20.wav
# ./audio/RedToBlue/VOX Back 05_10.wav
# ./audio/RedToBlue/VOXLeslie.01_08.wav
# ./audio/RedToBlue/VOXVamp.03_01.wav
# ./audio/RedToBlue/Kick.wav
# ./audio/RedToBlue/Snare.wav
# ./audio/RedToBlue/OH L.wav
# ./audio/RedToBlue/Oh R.wav
# ./audio/RedToBlue/Flr Tom.wav
# ./audio/RedToBlue/Tom 2.wav
# ./audio/RedToBlue/Tom 1.wav
# ./audio/RedToBlue/Room1 L.wav
# ./audio/RedToBlue/Room1 R.wav
# ./audio/RedToBlue/Tamb.wav
# ./audio/RedToBlue/Bass.wav
# ./audio/RedToBlue/GTR.09_01.wav
# ./audio/RedToBlue/GTR 1 OD.05_01.wav
# ./audio/RedToBlue/GTR 2.02_01.wav
# ./audio/RedToBlue/Gtr 3.03_01.wav
# ./audio/RedToBlue/Guitar 04_02.wav
# ./audio/RedToBlue/Leslie gtr.wav
# ./audio/RedToBlue/Slide Guitar.wav
# ./audio/RedToBlue/SoloGtr.wav
# ./audio/RedToBlue/Hmnd.wav
# ./audio/RedToBlue/VOX.wav
# ./audio/RedToBlue/John Double.wav
# ./audio/RedToBlue/VOXLeslie.01_08.wav
# ./audio/RedToBlue/John Hi_01 L.wav
# ./audio/RedToBlue/John Hi_01 R.wav
# ./audio/RedToBlue/Bop 01_06.wav
# ./audio/RedToBlue/Bop 02_05.wav
# ./audio/RedToBlue/Bop 03_04.wav
# ./audio/RedToBlue/VOX Double 01.dup1_04.wav
# ./audio/RedToBlue/VOX Double 01.dup2_02.wav
# ./audio/RedToBlue/VOX Back 01_05.wav
# ./audio/RedToBlue/VOX Back 01.dup1_12.wav
# ./audio/RedToBlue/VOX Back 01.dup2_10.wav
# ./audio/RedToBlue/VOX Back 03_09.wav
# ./audio/RedToBlue/VOX Back 04_20.wav
# ./audio/RedToBlue/VOX Back 05_10.wav
# ./audio/RedToBlue/VOXVamp.03_01.wav
# ./audio/IdLikeToKnow/KickBatter_16.wav
# Start time: 0
# ./audio/IdLikeToKnow/Kick_02.wav
# Start time: 0
# ./audio/IdLikeToKnow/SN_02.wav
# Start time: 0
# ./audio/IdLikeToKnow/SNBot_02.wav
# Start time: 0
# ./audio/IdLikeToKnow/T1_16.wav
# Start time: 0
# ./audio/IdLikeToKnow/T2_16.wav
# Start time: 0
# ./audio/IdLikeToKnow/OHL_02.wav
# Start time: 0
# ./audio/IdLikeToKnow/OHR_02.wav
# Start time: 0
# ./audio/IdLikeToKnow/DrRm_16.wav
# Start time: 0
# ./audio/IdLikeToKnow/Tmb.01_03.wav
# Start time: 0
# ./audio/IdLikeToKnow/Tmb_03.wav
# Start time: 160.0
# ./audio/IdLikeToKnow/BassDI_16.wav
# Start time: 0
# ./audio/IdLikeToKnow/AcGtr_05.wav
# Start time: 0
# ./audio/IdLikeToKnow/Gtr1.02_02.wav
# Start time: 0
# ./audio/IdLikeToKnow/Gtr2.08_02.wav
# Start time: 0
# ./audio/IdLikeToKnow/Gtr2.dup1.08_02.wav
# Start time: 48.0
# ./audio/IdLikeToKnow/Gtr3Rm_02.wav
